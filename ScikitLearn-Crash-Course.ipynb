# %% [markdown]
# # Scikit Learn Crash Course

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=0B5eIE_1vpU">Scikit Learn Crash Course</a>

# %%
import sklearn
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
X, y = fetch_california_housing(return_X_y=True)

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
# Import the model
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression

# %%
# Instanciate the model
mod = LinearRegression()

# %%
# Fit the model(give some data to train before giving results)
mod.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions with the model(Try the model that has been trained)
mod.predict(X)
# Out:
# array([4.13164983, 3.97660644, 3.67657094, ..., 0.17125141, 0.31910524,
#        0.51580363])

# %%
X.size
# Out:
# 165120

# %%
mod = KNeighborsRegressor().fit(X, y)

# Pipeline for scaling the model
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", KNeighborsRegressor(n_neighbors=1))
])
pipe.fit(X, y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', KNeighborsRegressor(n_neighbors=1))])

# %%
pred = pipe.predict(X)

# %%
plt.scatter(pred, y)

# %% [markdown]
# <img src="https://miro.medium.com/max/591/0*BgV2I0qTuqahH6Q_.png" alt="KNN" width="auto" height="auto">
